# %%
# %sql
SELECT COUNT(*) FROM marathos.gold.fct_results

# %%
# %sql
SELECT athlete_country, COUNT(*) FROM marathos.gold.dim_athlete GROUP BY 1 ORDER BY 2 DESC LIMIT 1

# %%
# %sql
SELECT e.event_name, COUNT(*) AS antal
FROM marathos.gold.fct_results f 
JOIN marathos.gold.dim_event e ON f.event_id = e.event_id 
GROUP BY 1 
ORDER BY 2 DESC 
LIMIT 1

# %%
# %sql
SELECT COUNT(DISTINCT event_id) FROM marathos.gold.dim_event

# %%
# %sql
SELECT AVG(2026 - athlete_year_of_birth) FROM marathos.gold.dim_athlete

# %%
# %sql
SELECT athlete_gender, COUNT(*) FROM marathos.gold.dim_athlete GROUP BY 1

# %%
# %sql
SELECT COUNT(*) FROM marathos.gold.fct_results;
SELECT COUNT(*) FROM marathos.gold.dim_event;
SELECT COUNT(*) FROM marathos.gold.dim_athlete;

# %%
# %sql
SELECT COUNT(*) FROM marathos.gold.fct_results

# %%
# %sql
SELECT COUNT(DISTINCT event_id) FROM marathos.gold.dim_event

# %%
# %sql
SELECT e.event_name, COUNT(*) AS antal
FROM marathos.gold.fct_results f
JOIN marathos.gold.dim_event e ON f.event_id = e.event_id
GROUP BY 1 ORDER BY 2 DESC LIMIT 1

# %%
# %sql
SELECT athlete_country, COUNT(DISTINCT athlete_id) AS antal
FROM marathos.gold.dim_athlete
WHERE athlete_country IS NOT NULL
GROUP BY 1 ORDER BY 2 DESC LIMIT 1
